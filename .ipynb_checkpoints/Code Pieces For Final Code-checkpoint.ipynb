# %%
import math 
import pandas as pd
user_goal = []
#payroll = int(input('Enter how much you get paid: '))
#goal_description = input('What are you saving up for? ')
#goalvalue = int(input('Enter how much do you want to save: '))
#amount = int(input('How much did you spend today?'))

#here is how the loop would occur  
#for i in goalvalue: 
    #if goalvalue < amount: 
        #print (goalvalue)
        #break

   
    return        
#here is how the user would input her amount
def add_item(user_goal):
    #todo write code here
        payroll = input ('Enter how much you get paid: ')
        for amount in user_goal:
            if amount == payroll:
                print( 'Amount added to goal' )
                return user_goal

        user_goal.append (payroll)
        return user_goal
    
def print_list(user_goal):
    #todo write code here
    user_goal.sort()
    print( user_goal )
    return user_goal

#Here is how the user would put in the amount she spent and it would be subtracted
def remove_item(user_goal):
    #todo write code here
    del_amount = input ('How much did you spend today? ')
    for amount in user_goal:
        if amount == del_amount:
            del_amount - goalvalue
            print ('You are' %s , 'closer to your goal')
            return user_goal
        
user_goal= []
while True:
    choice = input("Follow the steps below to calculate how much money you need to save:  ").upper()
    def print_menu():
    #print ("Follow the steps below to calculate how much money you need to save: ")
    print("M - Enter how much you get paid:")
    print("P - Display what you entered so far")
    print("D - How much did you spend today? ")
    print ("H - How much did you want to save today?")
    print("Q - You are done entering")
    if choice == 'M':
        user_goal = add_item(user_goal)
    elif choice == 'P':
        user_goal = print_list(user_goal)
    elif choice == 'D':
        user_goal = remove_item(user_goal)
    elif choice == "Q":
        break
    else:
        print('ERROR:', choice,'is not an option')        
    
#create a new file        
f= open (“my_expenses.csv”, 'x'):        
print(f.read)

#append to the file
f=open(“my_expenses.csv”, ‘a’’)
f.write(user_goal, goal_value, amount)
f.write(‘\n’)

#read the csv file into a dataframe
import warnings
warnings.filterwarnings('ignore')



Total_expense = pd.read_csv (‘my_expenses.csv’, delimiter=’ ’) (not sure if u need the delimiter here or not) 
total_expense.sample(10)

With open(‘my_expenses’) as ifile
Reader = csv.DictReader(ifile)
For row in reader:
print (row [‘user_goal’], row [‘amount’], row [‘goal_value])

url ="https://www.thesimpledollar.com/21-ways-to-reduce-your-spending-without-making-your-life-miserable/"
print(“Check here to reduce your spending:”, url)
